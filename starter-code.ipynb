# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Time Series EDA
#
# ----

# %% [markdown]
# This lab will walk you through performing exploratory data analysis on a dataset of weekly chickenpox cases from Hungary. This dataset is from the UCI Machine Learning Repository. You can read more about the dataset [**here**](https://archive.ics.uci.edu/ml/datasets/Hungarian+Chickenpox+Cases).
#
# -----

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Only using one county
pox = pd.read_csv('data/hungary_chickenpox.csv')[['Date', 'BUDAPEST']]

# %%
# Renaming columns for readability
pox.columns = ['date', 'budapest_cases']
pox.head(3)
# Out:
#          date  budapest_cases
# 0  03/01/2005             168
# 1  10/01/2005             157
# 2  17/01/2005              96

# %% [markdown]
# **Check the dataframe dtypes**

# %%
pox.dtypes
# Out:
# date              object
# budapest_cases     int64
# dtype: object

# %% [markdown]
# **Check for nulls**

# %%
pox.isnull().sum()
# Out:
# date              0
# budapest_cases    0
# dtype: int64

# %% [markdown]
# **Casting the Date column to a datetime type**
#
# Use **pd.to_datetime** to convert the Date column to a datetime.
#
# **WARNING**: The date column is formatted as day-month-year. Does **pd.to_datetime** work the way you expect it to on day/month/year strings? If it doesn't work the way you expect it to, check the [**documentation**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) for **pd.to_datetime**, and see if one of the settings fixes things.

# %%
pox['date'] = pd.to_datetime(pox['date'], format='%d/%m/%Y')

# show data types
pox.dtypes
# Out:
# date              datetime64[ns]
# budapest_cases             int64
# dtype: object

# %%
pox.head()
# Out:
#         date  budapest_cases
# 0 2005-01-03             168
# 1 2005-01-10             157
# 2 2005-01-17              96
# 3 2005-01-24             163
# 4 2005-01-31             122

# %% [markdown]
# **Set the **Date** column to be the index**

# %%
pox.set_index('date', inplace=True)

# show sample row
pox.head()
# Out:
#             budapest_cases
# date
# 2005-01-03             168
# 2005-01-10             157
# 2005-01-17              96
# 2005-01-24             163
# 2005-01-31             122

# %% [markdown]
# ---
#
# Now that our data is formatted appropriately, we can embark on EDA.
#
# ### Summary statistics
#
# **What times does the dataset describe?**
#
# That is, what's the earliest date in the dataset, and what's the latest date?

# %%
print(f'Earliest date: {pox.index.min()}')
print(f'Latest date: {pox.index.max()}')
# Out:
# Earliest date: 2005-01-03 00:00:00
# Latest date: 2014-12-29 00:00:00

# %% [markdown]
# **Plot a histogram of the Budapest cases column**

# %%
plt.figure(figsize=(10,5))
plt.hist(pox['budapest_cases'], bins=20, edgecolor='white')
plt.grid(True)
plt.xlabel('Cases')
plt.ylabel('Frequency')
plt.title('Histogram of Budapest Cases')
plt.xlim(left=0)
plt.show();

# %% [markdown]
# **How many cases were there per year?**
#
# Recall that with time series data, we can't simply group by on the year. You'll need to use the [**resample**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.resample.html) method on the DataFrame to answer this question.

# %%
pox['budapest_cases'].resample('YE').sum()
# Out:
# date
# 2005-12-31    4562
# 2006-12-31    6498
# 2007-12-31    6311
# 2008-12-31    4441
# 2009-12-31    5527
# 2010-12-31    5222
# 2011-12-31    5404
# 2012-12-31    5353
# 2013-12-31    5157
# 2014-12-31    4375
# Freq: YE-DEC, Name: budapest_cases, dtype: int64

# %% [markdown]
# ### Visualizations
#
# **Make a line plot of chickenpox cases**

# %%
pox.head()
# Out:
#             budapest_cases
# date
# 2005-01-03             168
# 2005-01-10             157
# 2005-01-17              96
# 2005-01-24             163
# 2005-01-31             122

# %%
plt.figure(figsize=(10,5))
# get trendline
z = np.polyfit(pox.index.values.astype('float'), pox['budapest_cases'], 1)
p = np.poly1d(z)

# plot case number
sns.lineplot(data=pox, y='budapest_cases', x=pox.index)
# plot trendline
sns.lineplot(data=pox, y=p(pox.index.values.astype('float')), x=pox.index)

# set labels
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Cases')
plt.title('Number of Chickenpox')
plt.show();

# %% [markdown]
# **In short answer format, describe any apparent trends**

# %% [markdown]
# - It has yearly seasonal
# - The trend is experiencing a decline

# %% [markdown]
# ### Plot rolling averages
#
# Plot the weekly chickenpox cases, but on the same graph, also plot the 4-week and 12-week rolling averages.

# %%
# calculate stats
weekly = pox['budapest_cases'].resample('W').sum()
rolling_4wk = weekly.rolling(window=4).mean()
rolling_12wk = weekly.rolling(window=12).mean()

# plot case number
plt.plot(weekly, color='green', label='Weekly Sum')
plt.plot(rolling_4wk, color='blue', label='Rolling Average 4 Weeks')
plt.plot(rolling_12wk, color='orange', label='Rolling Average 12 Weeks')

# set labels
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Cases')
plt.title('Weekly Chickenpox Cases')
plt.legend()
plt.show();

# %% [markdown]
# ### Plot yearly chickenpox cases
#
# You may need to use [**resample**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.resample.html) again for this.

# %%
# calculate stats
yearly = pox['budapest_cases'].resample('YE').sum()

# plot case number
plt.plot(yearly, label='Yearly Sum')

# set labels
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Cases')
plt.title('Yearly Chickenpox Cases')
plt.show();
